# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tmdb2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory=False)
tmdb2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
tmdb2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3666 entries, 0 to 3665
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3666 non-null   object
#  1   adult                  3665 non-null   float64
#  2   backdrop_path          1994 non-null   object
#  3   belongs_to_collection  336 non-null    object
#  4   budget                 3665 non-null   float64
#  5   genres                 3665 non-null   object
#  6   homepage               192 non-null    object
#  7   id                     3665 non-null   float64
#  8   original_language      3665 non-null   object
#  9   original_title         3665 non-null   object
#  10  overview               3593 non-null   object
#  11  popularity             3665 non-null   float64
#  12  poster_path            3293 non-null   object
#  13  production_companies   3665 non-null   object
# ...

# %%
tmdb2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory=False)
tmdb2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
tmdb2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4887 entries, 0 to 4886
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4887 non-null   object
#  1   adult                  4886 non-null   float64
#  2   backdrop_path          2658 non-null   object
#  3   belongs_to_collection  448 non-null    object
#  4   budget                 4886 non-null   float64
#  5   genres                 4886 non-null   object
#  6   homepage               256 non-null    object
#  7   id                     4886 non-null   float64
#  8   original_language      4886 non-null   object
#  9   original_title         4886 non-null   object
#  10  overview               4790 non-null   object
#  11  popularity             4886 non-null   float64
#  12  poster_path            4390 non-null   object
#  13  production_companies   4886 non-null   object
# ...

# %%
# Concatenate into one dataframe
df = pd.concat((tmdb2000, tmdb2001), axis = 0)
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8553 entries, 0 to 4886
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                8553 non-null   object
#  1   adult                  8551 non-null   float64
#  2   backdrop_path          4652 non-null   object
#  3   belongs_to_collection  784 non-null    object
#  4   budget                 8551 non-null   float64
#  5   genres                 8551 non-null   object
#  6   homepage               448 non-null    object
#  7   id                     8551 non-null   float64
#  8   original_language      8551 non-null   object
#  9   original_title         8551 non-null   object
#  10  overview               8383 non-null   object
#  11  popularity             8551 non-null   float64
#  12  poster_path            7683 non-null   object
#  13  production_companies   8551 non-null   object
# ...

# %%
## functionize a barplot and call it plot_bar

def plot_bar(data,x, y, figsize=(20,5)):
    ## Make a larger fig/ax before plotting
    fig, ax = plt.subplots(figsize=figsize)

    ## Plot barplot
    
    ## counts, counts up the categories, sort the values, then puts them in a 
    ## data frame.
    
    counts = df[x].value_counts().sort_values(ascending=False).to_frame()
    ## ploting the barplot

    sns.barplot(data=counts,x=counts.index, y = counts[x],ax=ax)

    plt.xticks(rotation= 90)
    ax.set_title(f'Categorical Frequencies of {y}', fontsize = 20, fontweight = 'bold');
    ax.set_xlabel(f'Categories for {y}', fontsize = 15, fontweight = 'bold')
    ax.set_ylabel('Counts', fontsize = 15, fontweight = 'bold')

    return fig,ax

# %% [markdown]
# How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# We exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
df = df[df.revenue != 0]
df = df[df.budget != 0]
df.count() # Below we can see there are 1168 movies with revenue and budget both positive
# Out:
# imdb_id                  1170
# adult                    1168
# backdrop_path            1140
# belongs_to_collection     315
# budget                   1168
# genres                   1168
# homepage                  105
# id                       1168
# original_language        1168
# original_title           1168
# overview                 1168
# popularity               1168
# poster_path              1168
# production_companies     1168
# production_countries     1168
# release_date             1168
# revenue                  1168
# runtime                  1168
# spoken_languages         1168
# status                   1168
# tagline                  1091
# title                    1168
# video                    1168
# vote_average             1168
# vote_count               1168
# certification            1028
# dtype: int64

# %% [markdown]
# How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
fig, ax = plot_bar(df, 'certification', 'certification');
plt.xlabel('Certification Category')
plt.ylabel('Count')
plt.title('Number of Movies in each Certification Category');
print(df['certification'].value_counts())
# Out:
# R        447
# PG-13    385
# PG       105
# G         56
# NR        35
# Name: certification, dtype: int64

# %% [markdown]
# What is the average revenue per certification category?

# %%
df.groupby('certification')['revenue'].mean()
# Out:
# certification
# G        1.053431e+08
# NR       2.024825e+07
# PG       9.198919e+07
# PG-13    1.131353e+08
# R        5.303487e+07
# Name: revenue, dtype: float64

# %%
g=sns.barplot(data=df, y='revenue', x='certification')
plt.title('Average Revenue per Certification Category')
plt.ylabel('Revenue')
plt.xlabel('Certification Category')
plt.ticklabel_format(style='plain',axis='y')
ylabels = ['$' + '{:,.0f}'.format(y) + 'M' for y in g.get_yticks()/1000000]
g.set_yticklabels(ylabels)
plt.show()
# Out:
# /var/folders/50/3xbvh4ss3131ch53yqb8sydr0000gn/T/ipykernel_5593/3054410981.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(ylabels)

# %% [markdown]
# What is the average budget per certification category?

# %%
df.groupby('certification')['budget'].mean()
# Out:
# certification
# G        4.500000e+07
# NR       1.606000e+07
# PG       5.421000e+07
# PG-13    4.826364e+07
# R        2.402843e+07
# Name: budget, dtype: float64

# %%
g=sns.barplot(data=df, y='budget', x='certification')
plt.title('Average Budget per Certification Category')
plt.ylabel('Budget')
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('Certification Category')
ylabels = ['$' + '{:,.0f}'.format(y) + 'M' for y in g.get_yticks()/1000000]
g.set_yticklabels(ylabels)
plt.show()
# Out:
# /var/folders/50/3xbvh4ss3131ch53yqb8sydr0000gn/T/ipykernel_5593/2095038290.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(ylabels)

# %%
# df.to_csv("Data/tmdb_results_combined.csv.gz", compression="gzip", index=False)
